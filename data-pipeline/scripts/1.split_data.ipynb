# %% [markdown]
# # Split data

# %%
import pandas as pd
import numpy as np
df_train = pd.read_csv('..\data\original\customer_churn_dataset-training-master.csv')
splits = np.array_split(df_train, 10)

df_p1, df_p2, df_p3, df_p4, df_p5, df_p6, df_p7, df_p8, df_p9, df_p10 = splits
for i, df in enumerate(splits, 1):
    df.to_csv(f'..\\data\\raw\\train_period_{i}.csv', index=False)
